# %%
#works 
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

sb.set()

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define the generator network
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.main = nn.Sequential(
            nn.Linear(2, 16),
            nn.LeakyReLU(0.2),
            nn.Linear(16, 16),
            nn.LeakyReLU(0.2),
            nn.Linear(16, 2)
        )

    def forward(self, input):
        return self.main(input)

# Define the discriminator network
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            nn.Linear(2, 16),
            nn.LeakyReLU(0.2),
            nn.Linear(16, 16),
            nn.LeakyReLU(0.2),
            nn.Linear(16, 2),
            nn.Linear(2, 1)
        )

    def forward(self, input):
        return self.main(input)

# Create instances of the generator and discriminator and move to device
generator = Generator().to(device)
discriminator = Discriminator().to(device)

# Loss function
criterion = nn.BCEWithLogitsLoss()

# Optimizers
gen_optimizer = optim.RMSprop(generator.parameters(), lr=0.001)
disc_optimizer = optim.RMSprop(discriminator.parameters(), lr=0.001)

# Function to generate noise
def sample_Z(m, n):
    return torch.Tensor(np.random.uniform(-1., 1., size=[m, n])).to(device)

# Load training data from m_hist.txt
def load_data(file_path):
    data = np.loadtxt(file_path, usecols=[0, 1])  # Load only the first two columns
    return torch.Tensor(data).to(device)

# Load your real training data
real_data_file = '/home/jovyan/blogs/basic-gans/code/muon_decay_data.txt'  # Full path to your data file
x_plot = load_data(real_data_file)

# Training parameters
batch_size = min(256, len(x_plot))  # Adjust batch size to be smaller than or equal to the number of data points
nd_steps = 10
ng_steps = 10
num_iterations = 4001  # Change to 12001 for 12000 epochs

# Training loop
for i in range(num_iterations):
    for _ in range(nd_steps):
        # Sample a batch of real data
        indices = np.random.choice(len(x_plot), batch_size, replace=False)
        X_batch = x_plot[indices]
        Z_batch = sample_Z(batch_size, 2)

        # Real data labels are 1, generated data labels are 0
        real_labels = torch.ones(batch_size, 1).to(device)
        fake_labels = torch.zeros(batch_size, 1).to(device)

        # Compute discriminator loss on real data
        real_outputs = discriminator(X_batch)
        real_loss = criterion(real_outputs, real_labels)

        # Compute discriminator loss on fake data
        fake_data = generator(Z_batch)
        fake_outputs = discriminator(fake_data.detach())
        fake_loss = criterion(fake_outputs, fake_labels)

        # Total discriminator loss
        disc_loss = real_loss + fake_loss

        # Backpropagation and optimization for discriminator
        disc_optimizer.zero_grad()
        disc_loss.backward()
        disc_optimizer.step()

    for _ in range(ng_steps):
        Z_batch = sample_Z(batch_size, 2)
        fake_data = generator(Z_batch)
        fake_outputs = discriminator(fake_data)

        # Generator loss
        gen_loss = criterion(fake_outputs, real_labels)

        # Backpropagation and optimization for generator
        gen_optimizer.zero_grad()
        gen_loss.backward()
        gen_optimizer.step()

    print(f"Iterations: {i}\t Discriminator loss: {disc_loss.item():.4f}\t Generator loss: {gen_loss.item():.4f}")

    if i % 1000 == 0:
        plt.figure()
        with torch.no_grad():
            g_plot = generator(sample_Z(batch_size, 2)).cpu().numpy()
        xax = plt.scatter(x_plot.cpu()[:, 0], x_plot.cpu()[:, 1], label='Real Data')
        gax = plt.scatter(g_plot[:, 0], g_plot[:, 1], label='Generated Data')

        plt.legend()
        plt.title(f'Samples at Iteration {i}')
        plt.tight_layout()
        plt.savefig(f'../plots/iterations/iteration_{i}.png')
        plt.close()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

sb.set()

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define the generator network
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.main = nn.Sequential(
            nn.Linear(2, 16),  # Input size is 2 (latent space)
            nn.LeakyReLU(0.2),
            nn.Linear(16, 16),
            nn.LeakyReLU(0.2),
            nn.Linear(16, 2)  # Output size should be 2 for 2D data
        )

    def forward(self, input):
        return self.main(input)

# Define the discriminator network
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            nn.Linear(2, 16),  # Input size should match the generated data size
            nn.LeakyReLU(0.2),
            nn.Linear(16, 16),
            nn.LeakyReLU(0.2),
            nn.Linear(16, 1)  # Output size is 1 for binary classification
        )

    def forward(self, input):
        return self.main(input)

# Create instances of the generator and discriminator and move to device
generator = Generator().to(device)
discriminator = Discriminator().to(device)

# Loss function
criterion = nn.BCEWithLogitsLoss()

# Optimizers
gen_optimizer = optim.RMSprop(generator.parameters(), lr=0.001)
disc_optimizer = optim.RMSprop(discriminator.parameters(), lr=0.001)

# Function to generate noise
def sample_Z(m, n):
    return torch.Tensor(np.random.uniform(-1., 1., size=[m, n])).to(device)

# Load training data from m_hist.txt
def load_data(file_path):
    # Load only the first two columns to avoid dimension mismatch
    data = np.loadtxt(file_path, usecols=[0, 1])  
    return torch.Tensor(data).to(device)

# Load your real training data
real_data_file = '/home/jovyan/blogs/basic-gans/code/muon_decay_data.txtt'  # Full path to your data file
x_plot = load_data(real_data_file)

# Training parameters
batch_size = min(256, len(x_plot))  # Adjust batch size to be smaller than or equal to the number of data points
nd_steps = 10
ng_steps = 10
num_iterations = 12001  # Set to 12000 iterations

# Training loop
for i in range(num_iterations):
    for _ in range(nd_steps):
        # Sample a batch of real data
        indices = np.random.choice(len(x_plot), batch_size, replace=False)
        X_batch = x_plot[indices]
        Z_batch = sample_Z(batch_size, 2)

        # Real data labels are 1, generated data labels are 0
        real_labels = torch.ones(batch_size, 1).to(device)
        fake_labels = torch.zeros(batch_size, 1).to(device)

        # Compute discriminator loss on real data
        real_outputs = discriminator(X_batch)
        real_loss = criterion(real_outputs, real_labels)

        # Compute discriminator loss on fake data
        fake_data = generator(Z_batch)
        fake_outputs = discriminator(fake_data.detach())
        fake_loss = criterion(fake_outputs, fake_labels)

        # Total discriminator loss
        disc_loss = real_loss + fake_loss

        # Backpropagation and optimization for discriminator
        disc_optimizer.zero_grad()
        disc_loss.backward()
        disc_optimizer.step()

    for _ in range(ng_steps):
        Z_batch = sample_Z(batch_size, 2)
        fake_data = generator(Z_batch)
        fake_outputs = discriminator(fake_data)

        # Generator loss
        gen_loss = criterion(fake_outputs, real_labels)

        # Backpropagation and optimization for generator
        gen_optimizer.zero_grad()
        gen_loss.backward()
        gen_optimizer.step()

    print(f"Iterations: {i}\t Discriminator loss: {disc_loss.item():.4f}\t Generator loss: {gen_loss.item():.4f}")

    # Plotting every 1000 iterations
    if i % 1000 == 0:
        plt.figure()
        with torch.no_grad():
            g_plot = generator(sample_Z(batch_size, 2)).cpu().numpy()  # Generate new data for plotting
        plt.scatter(x_plot.cpu()[:, 0], x_plot.cpu()[:, 1], label='Real Data')
        plt.scatter(g_plot[:, 0], g_plot[:, 1], label='Generated Data')

        plt.legend()
        plt.title(f'Samples at Iteration {i}')
        plt.tight_layout()
        plt.savefig(f'../plots/iterations/iteration_{i}.png')
        plt.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 5
#       3 import torch.optim as optim
#       4 import numpy as np
# ----> 5 import seaborn as sb
#       6 import matplotlib.pyplot as plt
#       8 sb.set()
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/seaborn/__init__.py:2
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/seaborn/rcmod.py:5
#       3 import matplotlib as mpl
#       4 from cycler import cycler
# ----> 5 from . import palettes
#       8 __all__ = ["set_theme", "set", "reset_defaults", "reset_orig",
#       9            "axes_style", "set_style", "plotting_context", "set_context",
#      10            "set_palette"]
#      13 _style_keys = [
#      14
#      15     "axes.facecolor",
#    (...)
#      50
#      51 ]
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/seaborn/palettes.py:9
#       5 import matplotlib as mpl
#       7 from .external import husl
# ----> 9 from .utils import desaturate, get_color_cycle
#      10 from .colors import xkcd_rgb, crayons
#      11 from ._compat import get_colormap
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/seaborn/utils.py:11
#       8 from types import ModuleType
#      10 import numpy as np
# ---> 11 import pandas as pd
#      12 import matplotlib as mpl
#      13 from matplotlib.colors import to_rgb
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pandas/__init__.py:22
#      19 del _hard_dependencies, _dependency, _missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev  # pyright: ignore # noqa:F401
#      24 try:
#      25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pandas/compat/__init__.py:18
#      15 from typing import TYPE_CHECKING
#      17 from pandas._typing import F
# ---> 18 from pandas.compat.numpy import (
#      19     is_numpy_dev,
#      20     np_version_under1p21,
#      21 )
#      22 from pandas.compat.pyarrow import (
#      23     pa_version_under1p01,
#      24     pa_version_under2p0,
#    (...)
#      31     pa_version_under9p0,
#      32 )
#      34 if TYPE_CHECKING:
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pandas/compat/numpy/__init__.py:4
#       1 """ support numpy compatibility across versions """
#       2 import numpy as np
# ----> 4 from pandas.util.version import Version
#       6 # numpy versioning
#       7 _np_version = np.__version__
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pandas/util/__init__.py:2
#       1 # pyright: reportUnusedImport = false
# ----> 2 from pandas.util._decorators import (  # noqa:F401
#       3     Appender,
#       4     Substitution,
#       5     cache_readonly,
#       6 )
#       8 from pandas.core.util.hashing import (  # noqa:F401
#       9     hash_array,
#      10     hash_pandas_object,
#      11 )
#      14 def __getattr__(name):
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pandas/util/_decorators.py:14
#       6 from typing import (
#       7     Any,
#       8     Callable,
#       9     Mapping,
#      10     cast,
#      11 )
#      12 import warnings
# ---> 14 from pandas._libs.properties import cache_readonly
#      15 from pandas._typing import (
#      16     F,
#      17     T,
#      18 )
#      19 from pandas.util._exceptions import find_stack_level
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pandas/_libs/__init__.py:13
#       1 __all__ = [
#       2     "NaT",
#       3     "NaTType",
#    (...)
#       9     "Interval",
#      10 ]
# ---> 13 from pandas._libs.interval import Interval
#      14 from pandas._libs.tslibs import (
#      15     NaT,
#      16     NaTType,
#    (...)
#      21     iNaT,
#      22 )
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pandas/_libs/interval.pyx:1, in init pandas._libs.interval()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define the generator network
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.main = nn.Sequential(
            nn.Linear(2, 16),  # Input size is 2 (latent space)
            nn.LeakyReLU(0.2),
            nn.Linear(16, 16),
            nn.LeakyReLU(0.2),
            nn.Linear(16, 2)  # Output size should be 2 for 2D data
        )

    def forward(self, input):
        return self.main(input)

# Define the discriminator network
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            nn.Linear(2, 16),  # Input size should match the generated data size
            nn.LeakyReLU(0.2),
            nn.Linear(16, 16),
            nn.LeakyReLU(0.2),
            nn.Linear(16, 1)  # Output size is 1 for binary classification
        )

    def forward(self, input):
        return self.main(input)

# Create instances of the generator and discriminator and move to device
generator = Generator().to(device)
discriminator = Discriminator().to(device)

# Loss function
criterion = nn.BCEWithLogitsLoss()

# Optimizers
gen_optimizer = optim.RMSprop(generator.parameters(), lr=0.001)
disc_optimizer = optim.RMSprop(discriminator.parameters(), lr=0.001)

# Function to generate noise
def sample_Z(m, n):
    return torch.Tensor(np.random.uniform(-1., 1., size=[m, n])).to(device)

# Load training data from m_hist.txt
def load_data(file_path):
    # Load only the first two columns to avoid dimension mismatch
    data = np.loadtxt(file_path, usecols=[0, 1])  
    return torch.Tensor(data).to(device)

# Load your real training data
real_data_file = '/home/jovyan/plots-gan/basic-gans/code/muon_decay_data.txt'  # Full path to your data file
x_plot = load_data(real_data_file)

# Training parameters
batch_size = min(256, len(x_plot))  # Adjust batch size to be smaller than or equal to the number of data points
nd_steps = 10
ng_steps = 10
num_iterations = 35001  # Set to 12000 iterations

# Training loop
for i in range(num_iterations):
    for _ in range(nd_steps):
        # Sample a batch of real data
        indices = np.random.choice(len(x_plot), batch_size, replace=False)
        X_batch = x_plot[indices]
        Z_batch = sample_Z(batch_size, 2)

        # Real data labels are 1, generated data labels are 0
        real_labels = torch.ones(batch_size, 1).to(device)
        fake_labels = torch.zeros(batch_size, 1).to(device)

        # Compute discriminator loss on real data
        real_outputs = discriminator(X_batch)
        real_loss = criterion(real_outputs, real_labels)

        # Compute discriminator loss on fake data
        fake_data = generator(Z_batch)
        fake_outputs = discriminator(fake_data.detach())
        fake_loss = criterion(fake_outputs, fake_labels)

        # Total discriminator loss
        disc_loss = real_loss + fake_loss

        # Backpropagation and optimization for discriminator
        disc_optimizer.zero_grad()
        disc_loss.backward()
        disc_optimizer.step()

    for _ in range(ng_steps):
        Z_batch = sample_Z(batch_size, 2)
        fake_data = generator(Z_batch)
        fake_outputs = discriminator(fake_data)

        # Generator loss
        gen_loss = criterion(fake_outputs, real_labels)

        # Backpropagation and optimization for generator
        gen_optimizer.zero_grad()
        gen_loss.backward()
        gen_optimizer.step()

    print(f"Iterations: {i}\t Discriminator loss: {disc_loss.item():.4f}\t Generator loss: {gen_loss.item():.4f}")

    # Plotting every 1000 iterations
    if i % 1000 == 0:
        plt.figure()
        with torch.no_grad():
            g_plot = generator(sample_Z(batch_size, 2)).cpu().numpy()  # Generate new data for plotting
        plt.scatter(x_plot.cpu()[:, 0], x_plot.cpu()[:, 1], color='blue', label='Real Data', alpha=0.6)
        plt.scatter(g_plot[:, 0], g_plot[:, 1], color='orange', label='Generated Data', alpha=0.6)

        plt.legend()
        plt.title(f'Samples at Iteration {i}', fontsize=14)
        plt.xlabel('X-axis Label', fontsize=12)
        plt.ylabel('Y-axis Label', fontsize=12)
        plt.grid(True)
        plt.tight_layout()
        plt.savefig(f'../plots/iterations/iteration_{i}.png', dpi=300)
        plt.close()
# Out:
# Iterations: 0	 Discriminator loss: 0.6292	 Generator loss: 0.7238
# Iterations: 1	 Discriminator loss: 0.6108	 Generator loss: 0.7532
# Iterations: 2	 Discriminator loss: 0.5913	 Generator loss: 0.7775
# Iterations: 3	 Discriminator loss: 0.5675	 Generator loss: 0.8243
# Iterations: 4	 Discriminator loss: 0.5296	 Generator loss: 0.8859
# Iterations: 5	 Discriminator loss: 0.4873	 Generator loss: 0.9566
# Iterations: 6	 Discriminator loss: 0.4425	 Generator loss: 1.0353
# Iterations: 7	 Discriminator loss: 0.3995	 Generator loss: 1.1148
# Iterations: 8	 Discriminator loss: 0.3620	 Generator loss: 1.1871
# Iterations: 9	 Discriminator loss: 0.3337	 Generator loss: 1.2476
# Iterations: 10	 Discriminator loss: 0.3144	 Generator loss: 1.2947
# Iterations: 11	 Discriminator loss: 0.2980	 Generator loss: 1.3525
# Iterations: 12	 Discriminator loss: 0.2771	 Generator loss: 1.4208
# Iterations: 13	 Discriminator loss: 0.2550	 Generator loss: 1.4924
# Iterations: 14	 Discriminator loss: 0.2331	 Generator loss: 1.5649
# Iterations: 15	 Discriminator loss: 0.2140	 Generator loss: 1.6398
# Iterations: 16	 Discriminator loss: 0.1963	 Generator loss: 1.7126
# Iterations: 17	 Discriminator loss: 0.1810	 Generator loss: 1.7849
# Iterations: 18	 Discriminator loss: 0.1675	 Generator loss: 1.8623
# Iterations: 19	 Discriminator loss: 0.1509	 Generator loss: 1.9733
# Iterations: 20	 Discriminator loss: 0.1334	 Generator loss: 2.0860
# Iterations: 21	 Discriminator loss: 0.1186	 Generator loss: 2.1927
# Iterations: 22	 Discriminator loss: 0.1062	 Generator loss: 2.2894
# Iterations: 23	 Discriminator loss: 0.0958	 Generator loss: 2.3846
# Iterations: 24	 Discriminator loss: 0.0867	 Generator loss: 2.4803
# Iterations: 25	 Discriminator loss: 0.0784	 Generator loss: 2.5730
# Iterations: 26	 Discriminator loss: 0.0709	 Generator loss: 2.6768
# Iterations: 27	 Discriminator loss: 0.0634	 Generator loss: 2.7942
# Iterations: 28	 Discriminator loss: 0.0565	 Generator loss: 2.9071
# Iterations: 29	 Discriminator loss: 0.0508	 Generator loss: 2.9976
# Iterations: 30	 Discriminator loss: 0.0468	 Generator loss: 3.0583
# Iterations: 31	 Discriminator loss: 0.0441	 Generator loss: 3.1238
# Iterations: 32	 Discriminator loss: 0.0409	 Generator loss: 3.2251
# Iterations: 33	 Discriminator loss: 0.0369	 Generator loss: 3.3307
# Iterations: 34	 Discriminator loss: 0.0332	 Generator loss: 3.4338
# Iterations: 35	 Discriminator loss: 0.0299	 Generator loss: 3.5370
# Iterations: 36	 Discriminator loss: 0.0270	 Generator loss: 3.6399
# Iterations: 37	 Discriminator loss: 0.0243	 Generator loss: 3.7416
# Iterations: 38	 Discriminator loss: 0.0220	 Generator loss: 3.8418
# Iterations: 39	 Discriminator loss: 0.0199	 Generator loss: 3.9400
# Iterations: 40	 Discriminator loss: 0.0181	 Generator loss: 4.0353
# Iterations: 41	 Discriminator loss: 0.0165	 Generator loss: 4.1258
# Iterations: 42	 Discriminator loss: 0.0151	 Generator loss: 4.2101
# Iterations: 43	 Discriminator loss: 0.0139	 Generator loss: 4.2900
# Iterations: 44	 Discriminator loss: 0.0128	 Generator loss: 4.3683
# Iterations: 45	 Discriminator loss: 0.0118	 Generator loss: 4.4336
# Iterations: 46	 Discriminator loss: 0.0111	 Generator loss: 4.5015
# Iterations: 47	 Discriminator loss: 0.0102	 Generator loss: 4.5797
# Iterations: 48	 Discriminator loss: 0.0093	 Generator loss: 4.6732
# Iterations: 49	 Discriminator loss: 0.0085	 Generator loss: 4.7754
# Iterations: 50	 Discriminator loss: 0.0077	 Generator loss: 4.8570
# Iterations: 51	 Discriminator loss: 0.0071	 Generator loss: 4.9291
# Iterations: 52	 Discriminator loss: 0.0066	 Generator loss: 5.0006
# Iterations: 53	 Discriminator loss: 0.0062	 Generator loss: 5.0714
# Iterations: 54	 Discriminator loss: 0.0058	 Generator loss: 5.1451
# Iterations: 55	 Discriminator loss: 0.0053	 Generator loss: 5.2299
# Iterations: 56	 Discriminator loss: 0.0049	 Generator loss: 5.2947
# Iterations: 57	 Discriminator loss: 0.0046	 Generator loss: 5.3686
# Iterations: 58	 Discriminator loss: 0.0043	 Generator loss: 5.4410
# Iterations: 59	 Discriminator loss: 0.0040	 Generator loss: 5.5231
# Iterations: 60	 Discriminator loss: 0.0037	 Generator loss: 5.5872
# Iterations: 61	 Discriminator loss: 0.0035	 Generator loss: 5.6728
# Iterations: 62	 Discriminator loss: 0.0032	 Generator loss: 5.7585
# Iterations: 63	 Discriminator loss: 0.0029	 Generator loss: 5.8416
# Iterations: 64	 Discriminator loss: 0.0027	 Generator loss: 5.9208
# Iterations: 65	 Discriminator loss: 0.0025	 Generator loss: 5.9765
# Iterations: 66	 Discriminator loss: 0.0024	 Generator loss: 6.0269
# Iterations: 67	 Discriminator loss: 0.0023	 Generator loss: 6.0314
# Iterations: 68	 Discriminator loss: 0.0022	 Generator loss: 6.0937
# Iterations: 69	 Discriminator loss: 0.0020	 Generator loss: 6.2159
# Iterations: 70	 Discriminator loss: 0.0017	 Generator loss: 6.3748
# Iterations: 71	 Discriminator loss: 0.0015	 Generator loss: 6.5249
# Iterations: 72	 Discriminator loss: 0.0013	 Generator loss: 6.6337
# Iterations: 73	 Discriminator loss: 0.0012	 Generator loss: 6.6981
# Iterations: 74	 Discriminator loss: 0.0012	 Generator loss: 6.6756
# Iterations: 75	 Discriminator loss: 0.0012	 Generator loss: 6.6179
# Iterations: 76	 Discriminator loss: 0.0013	 Generator loss: 6.5633
# Iterations: 77	 Discriminator loss: 0.0013	 Generator loss: 6.5498
# Iterations: 78	 Discriminator loss: 0.0013	 Generator loss: 6.6265
# Iterations: 79	 Discriminator loss: 0.0012	 Generator loss: 6.0989
# Iterations: 80	 Discriminator loss: 0.0014	 Generator loss: 6.2097
# Iterations: 81	 Discriminator loss: 0.0012	 Generator loss: 6.5874
# Iterations: 82	 Discriminator loss: 0.0009	 Generator loss: 6.8962
# Iterations: 83	 Discriminator loss: 0.0007	 Generator loss: 7.1300
# Iterations: 84	 Discriminator loss: 0.0006	 Generator loss: 7.3346
# Iterations: 85	 Discriminator loss: 0.0005	 Generator loss: 7.6082
# Iterations: 86	 Discriminator loss: 0.0004	 Generator loss: 7.9363
# Iterations: 87	 Discriminator loss: 0.0003	 Generator loss: 8.2292
# Iterations: 88	 Discriminator loss: 0.0002	 Generator loss: 8.4783
# Iterations: 89	 Discriminator loss: 0.0002	 Generator loss: 8.6702
# Iterations: 90	 Discriminator loss: 0.0002	 Generator loss: 8.8030
# Iterations: 91	 Discriminator loss: 0.0001	 Generator loss: 8.8798
# Iterations: 92	 Discriminator loss: 0.0001	 Generator loss: 8.9050
# Iterations: 93	 Discriminator loss: 0.0001	 Generator loss: 8.8863
# Iterations: 94	 Discriminator loss: 0.0001	 Generator loss: 8.8328
# Iterations: 95	 Discriminator loss: 0.0001	 Generator loss: 8.7605
# Iterations: 96	 Discriminator loss: 0.0002	 Generator loss: 8.6763
# Iterations: 97	 Discriminator loss: 0.0002	 Generator loss: 8.5880
# Iterations: 98	 Discriminator loss: 0.0002	 Generator loss: 8.5085
# Iterations: 99	 Discriminator loss: 0.0002	 Generator loss: 8.4035
# Iterations: 100	 Discriminator loss: 0.0002	 Generator loss: 8.3272
# Iterations: 101	 Discriminator loss: 0.0002	 Generator loss: 8.4451
# Iterations: 102	 Discriminator loss: 0.0002	 Generator loss: 8.5940
# Iterations: 103	 Discriminator loss: 0.0002	 Generator loss: 8.7452
# Iterations: 104	 Discriminator loss: 0.0001	 Generator loss: 8.8839
# Iterations: 105	 Discriminator loss: 0.0001	 Generator loss: 8.9334
# Iterations: 106	 Discriminator loss: 0.0001	 Generator loss: 8.9462
# Iterations: 107	 Discriminator loss: 0.0001	 Generator loss: 8.7732
# Iterations: 108	 Discriminator loss: 0.0002	 Generator loss: 8.8007
# Iterations: 109	 Discriminator loss: 0.0002	 Generator loss: 8.6620
# Iterations: 110	 Discriminator loss: 0.0217	 Generator loss: 2.8956
# Iterations: 111	 Discriminator loss: 0.0196	 Generator loss: 3.7502
# Iterations: 112	 Discriminator loss: 0.0126	 Generator loss: 4.2920
# Iterations: 113	 Discriminator loss: 0.0083	 Generator loss: 4.8251
# Iterations: 114	 Discriminator loss: 0.0054	 Generator loss: 5.2780
# Iterations: 115	 Discriminator loss: 0.0040	 Generator loss: 5.6204
# Iterations: 116	 Discriminator loss: 0.0033	 Generator loss: 5.7743
# Iterations: 117	 Discriminator loss: 0.0026	 Generator loss: 6.1855
# Iterations: 118	 Discriminator loss: 0.0021	 Generator loss: 6.2752
# Iterations: 119	 Discriminator loss: 0.0017	 Generator loss: 6.5877
# Iterations: 120	 Discriminator loss: 0.0017	 Generator loss: 6.6798
# Iterations: 121	 Discriminator loss: 0.0021	 Generator loss: 6.5396
# Iterations: 122	 Discriminator loss: 0.0022	 Generator loss: 6.5285
# Iterations: 123	 Discriminator loss: 0.0026	 Generator loss: 6.4567
# Iterations: 124	 Discriminator loss: 0.0028	 Generator loss: 6.3249
# Iterations: 125	 Discriminator loss: 0.0031	 Generator loss: 6.3291
# Iterations: 126	 Discriminator loss: 0.0034	 Generator loss: 6.2441
# Iterations: 127	 Discriminator loss: 0.0036	 Generator loss: 6.2409
# Iterations: 128	 Discriminator loss: 0.0037	 Generator loss: 6.1158
# Iterations: 129	 Discriminator loss: 0.0042	 Generator loss: 5.9078
# Iterations: 130	 Discriminator loss: 0.0048	 Generator loss: 5.6909
# Iterations: 131	 Discriminator loss: 0.0055	 Generator loss: 5.6369
# Iterations: 132	 Discriminator loss: 0.0073	 Generator loss: 5.3190
# Iterations: 133	 Discriminator loss: 2.5930	 Generator loss: 1.0557
# Iterations: 134	 Discriminator loss: 0.0182	 Generator loss: 3.3077
# Iterations: 135	 Discriminator loss: 0.0314	 Generator loss: 3.3198
# Iterations: 136	 Discriminator loss: 0.0626	 Generator loss: 2.8470
# Iterations: 137	 Discriminator loss: 0.1011	 Generator loss: 2.6486
# Iterations: 138	 Discriminator loss: 0.1119	 Generator loss: 2.6760
# Iterations: 139	 Discriminator loss: 0.1169	 Generator loss: 3.0951
# Iterations: 140	 Discriminator loss: 0.0837	 Generator loss: 3.1627
# Iterations: 141	 Discriminator loss: 0.0625	 Generator loss: 3.4787
# Iterations: 142	 Discriminator loss: 0.0530	 Generator loss: 3.6938
# Iterations: 143	 Discriminator loss: 0.0461	 Generator loss: 3.7656
# Iterations: 144	 Discriminator loss: 0.0462	 Generator loss: 3.6258
# Iterations: 145	 Discriminator loss: 0.0483	 Generator loss: 3.5039
# Iterations: 146	 Discriminator loss: 0.0535	 Generator loss: 3.4241
# Iterations: 147	 Discriminator loss: 0.0719	 Generator loss: 3.2786
# Iterations: 148	 Discriminator loss: 1.3225	 Generator loss: 0.0026
# Iterations: 149	 Discriminator loss: 1.0125	 Generator loss: 0.5536
# Iterations: 150	 Discriminator loss: 0.1473	 Generator loss: 2.6160
# Iterations: 151	 Discriminator loss: 0.1757	 Generator loss: 2.4948
# Iterations: 152	 Discriminator loss: 0.2304	 Generator loss: 1.7526
# Iterations: 153	 Discriminator loss: 0.9517	 Generator loss: 0.6022
# Iterations: 154	 Discriminator loss: 0.3245	 Generator loss: 1.7936
# Iterations: 155	 Discriminator loss: 0.2834	 Generator loss: 2.2066
# Iterations: 156	 Discriminator loss: 0.3186	 Generator loss: 2.1011
# Iterations: 157	 Discriminator loss: 1.0618	 Generator loss: 0.6048
# Iterations: 158	 Discriminator loss: 0.3462	 Generator loss: 1.8092
# Iterations: 159	 Discriminator loss: 0.3818	 Generator loss: 1.6368
# Iterations: 160	 Discriminator loss: 0.8483	 Generator loss: 0.9386
# Iterations: 161	 Discriminator loss: 1.5931	 Generator loss: 0.6675
# Iterations: 162	 Discriminator loss: 0.8602	 Generator loss: 0.8460
# Iterations: 163	 Discriminator loss: 1.3832	 Generator loss: 0.7005
# Iterations: 164	 Discriminator loss: 1.8161	 Generator loss: 0.5165
# Iterations: 165	 Discriminator loss: 1.4402	 Generator loss: 0.6204
# Iterations: 166	 Discriminator loss: 1.7850	 Generator loss: 0.4749
# Iterations: 167	 Discriminator loss: 1.7918	 Generator loss: 0.4910
# Iterations: 168	 Discriminator loss: 1.8023	 Generator loss: 0.4534
# Iterations: 169	 Discriminator loss: 1.8055	 Generator loss: 0.4462
# Iterations: 170	 Discriminator loss: 1.8652	 Generator loss: 0.3935
# Iterations: 171	 Discriminator loss: 2.0268	 Generator loss: 0.3263
# Iterations: 172	 Discriminator loss: 1.8165	 Generator loss: 0.4302
# Iterations: 173	 Discriminator loss: 1.9061	 Generator loss: 0.3307
# Iterations: 174	 Discriminator loss: 2.2119	 Generator loss: 0.2991
# Iterations: 175	 Discriminator loss: 1.5947	 Generator loss: 0.4380
# Iterations: 176	 Discriminator loss: 2.3119	 Generator loss: 0.2641
# Iterations: 177	 Discriminator loss: 1.7948	 Generator loss: 0.4267
# Iterations: 178	 Discriminator loss: 2.1021	 Generator loss: 0.3229
# Iterations: 179	 Discriminator loss: 2.0339	 Generator loss: 0.3749
# Iterations: 180	 Discriminator loss: 2.1338	 Generator loss: 0.3774
# Iterations: 181	 Discriminator loss: 2.1989	 Generator loss: 0.3655
# Iterations: 182	 Discriminator loss: 2.4134	 Generator loss: 0.3309
# Iterations: 183	 Discriminator loss: 2.5008	 Generator loss: 0.3022
# Iterations: 184	 Discriminator loss: 2.7559	 Generator loss: 0.2537
# Iterations: 185	 Discriminator loss: 2.8701	 Generator loss: 0.2416
# Iterations: 186	 Discriminator loss: 3.0007	 Generator loss: 0.2060
# Iterations: 187	 Discriminator loss: 3.1305	 Generator loss: 0.1796
# Iterations: 188	 Discriminator loss: 3.2058	 Generator loss: 0.1575
# Iterations: 189	 Discriminator loss: 3.1852	 Generator loss: 0.1534
# Iterations: 190	 Discriminator loss: 3.1806	 Generator loss: 0.1451
# Iterations: 191	 Discriminator loss: 3.1749	 Generator loss: 0.1395
# Iterations: 192	 Discriminator loss: 3.1551	 Generator loss: 0.1308
# Iterations: 193	 Discriminator loss: 3.2278	 Generator loss: 0.1129
# Iterations: 194	 Discriminator loss: 3.1789	 Generator loss: 0.1179
# Iterations: 195	 Discriminator loss: 3.2065	 Generator loss: 0.1173
# Iterations: 196	 Discriminator loss: 3.2517	 Generator loss: 0.1140
# Iterations: 197	 Discriminator loss: 3.2589	 Generator loss: 0.1253
# Iterations: 198	 Discriminator loss: 3.2948	 Generator loss: 0.1320
# Iterations: 199	 Discriminator loss: 3.3326	 Generator loss: 0.1321
# Iterations: 200	 Discriminator loss: 3.3961	 Generator loss: 0.1324
# Iterations: 201	 Discriminator loss: 3.5143	 Generator loss: 0.1248
# Iterations: 202	 Discriminator loss: 3.6000	 Generator loss: 0.1204
# Iterations: 203	 Discriminator loss: 3.7112	 Generator loss: 0.1121
# Iterations: 204	 Discriminator loss: 3.7677	 Generator loss: 0.0990
# Iterations: 205	 Discriminator loss: 3.8793	 Generator loss: 0.0830
# Iterations: 206	 Discriminator loss: 3.8955	 Generator loss: 0.0781
# Iterations: 207	 Discriminator loss: 3.9519	 Generator loss: 0.0629
# Iterations: 208	 Discriminator loss: 3.9513	 Generator loss: 0.0601
# Iterations: 209	 Discriminator loss: 3.9712	 Generator loss: 0.0545
# Iterations: 210	 Discriminator loss: 3.9627	 Generator loss: 0.0528
# Iterations: 211	 Discriminator loss: 3.9696	 Generator loss: 0.0493
# Iterations: 212	 Discriminator loss: 3.9895	 Generator loss: 0.0470
# Iterations: 213	 Discriminator loss: 3.9806	 Generator loss: 0.0488
# Iterations: 214	 Discriminator loss: 4.0392	 Generator loss: 0.0475
# Iterations: 215	 Discriminator loss: 4.0802	 Generator loss: 0.0473
# Iterations: 216	 Discriminator loss: 4.1219	 Generator loss: 0.0483
# Iterations: 217	 Discriminator loss: 4.1520	 Generator loss: 0.0520
# Iterations: 218	 Discriminator loss: 4.1856	 Generator loss: 0.0496
# Iterations: 219	 Discriminator loss: 4.2589	 Generator loss: 0.0466
# Iterations: 220	 Discriminator loss: 4.3110	 Generator loss: 0.0440
# Iterations: 221	 Discriminator loss: 4.3528	 Generator loss: 0.0406
# Iterations: 222	 Discriminator loss: 4.3962	 Generator loss: 0.0361
# Iterations: 223	 Discriminator loss: 4.4052	 Generator loss: 0.0315
# Iterations: 224	 Discriminator loss: 4.4137	 Generator loss: 0.0295
# Iterations: 225	 Discriminator loss: 4.4209	 Generator loss: 0.0270
# Iterations: 226	 Discriminator loss: 4.4410	 Generator loss: 0.0245
# Iterations: 227	 Discriminator loss: 4.4364	 Generator loss: 0.0236
# Iterations: 228	 Discriminator loss: 4.4518	 Generator loss: 0.0221
# Iterations: 229	 Discriminator loss: 4.4529	 Generator loss: 0.0222
# Iterations: 230	 Discriminator loss: 4.4695	 Generator loss: 0.0218
# Iterations: 231	 Discriminator loss: 4.5049	 Generator loss: 0.0212
# Iterations: 232	 Discriminator loss: 4.5477	 Generator loss: 0.0209
# Iterations: 233	 Discriminator loss: 4.5957	 Generator loss: 0.0215
# Iterations: 234	 Discriminator loss: 4.6411	 Generator loss: 0.0201
# Iterations: 235	 Discriminator loss: 4.6395	 Generator loss: 0.0204
# Iterations: 236	 Discriminator loss: 4.6702	 Generator loss: 0.0183
# Iterations: 237	 Discriminator loss: 4.6834	 Generator loss: 0.0171
# Iterations: 238	 Discriminator loss: 4.7219	 Generator loss: 0.0152
# Iterations: 239	 Discriminator loss: 4.7118	 Generator loss: 0.0140
# Iterations: 240	 Discriminator loss: 4.7036	 Generator loss: 0.0133
# Iterations: 241	 Discriminator loss: 4.7146	 Generator loss: 0.0123
# Iterations: 242	 Discriminator loss: 4.7209	 Generator loss: 0.0114
# Iterations: 243	 Discriminator loss: 4.7447	 Generator loss: 0.0106
# Iterations: 244	 Discriminator loss: 4.7567	 Generator loss: 0.0109
# Iterations: 245	 Discriminator loss: 4.7870	 Generator loss: 0.0104
# Iterations: 246	 Discriminator loss: 4.7889	 Generator loss: 0.0107
# Iterations: 247	 Discriminator loss: 4.8376	 Generator loss: 0.0102
# Iterations: 248	 Discriminator loss: 4.8631	 Generator loss: 0.0101
# Iterations: 249	 Discriminator loss: 4.8691	 Generator loss: 0.0099
# Iterations: 250	 Discriminator loss: 4.9273	 Generator loss: 0.0089
# Iterations: 251	 Discriminator loss: 4.9168	 Generator loss: 0.0087
# Iterations: 252	 Discriminator loss: 4.9578	 Generator loss: 0.0077
# Iterations: 253	 Discriminator loss: 4.9465	 Generator loss: 0.0072
# Iterations: 254	 Discriminator loss: 4.9600	 Generator loss: 0.0068
# Iterations: 255	 Discriminator loss: 4.9731	 Generator loss: 0.0063
# Iterations: 256	 Discriminator loss: 4.9144	 Generator loss: 0.0064
# Iterations: 257	 Discriminator loss: 4.9679	 Generator loss: 0.0060
# Iterations: 258	 Discriminator loss: 4.9796	 Generator loss: 0.0058
# Iterations: 259	 Discriminator loss: 5.0026	 Generator loss: 0.0058
# Iterations: 260	 Discriminator loss: 5.0456	 Generator loss: 0.0057
# Iterations: 261	 Discriminator loss: 5.0617	 Generator loss: 0.0055
# Iterations: 262	 Discriminator loss: 5.0854	 Generator loss: 0.0054
# Iterations: 263	 Discriminator loss: 5.1216	 Generator loss: 0.0053
# Iterations: 264	 Discriminator loss: 5.1520	 Generator loss: 0.0049
# Iterations: 265	 Discriminator loss: 5.1675	 Generator loss: 0.0047
# Iterations: 266	 Discriminator loss: 5.1672	 Generator loss: 0.0046
# Iterations: 267	 Discriminator loss: 5.1734	 Generator loss: 0.0043
# Iterations: 268	 Discriminator loss: 5.2204	 Generator loss: 0.0041
# Iterations: 269	 Discriminator loss: 5.2560	 Generator loss: 0.0040
# Iterations: 270	 Discriminator loss: 5.2814	 Generator loss: 0.0039
# Iterations: 271	 Discriminator loss: 5.3505	 Generator loss: 0.0039
# Iterations: 272	 Discriminator loss: 5.4294	 Generator loss: 0.0039
# Iterations: 273	 Discriminator loss: 5.4597	 Generator loss: 0.0040
# Iterations: 274	 Discriminator loss: 5.5263	 Generator loss: 0.0040
# Iterations: 275	 Discriminator loss: 5.6026	 Generator loss: 0.0040
# Iterations: 276	 Discriminator loss: 5.6943	 Generator loss: 0.0041
# Iterations: 277	 Discriminator loss: 5.7899	 Generator loss: 0.0042
# Iterations: 278	 Discriminator loss: 5.9296	 Generator loss: 0.0044
# Iterations: 279	 Discriminator loss: 6.1200	 Generator loss: 0.0050
# Iterations: 280	 Discriminator loss: 6.3402	 Generator loss: 0.0058
# Iterations: 281	 Discriminator loss: 6.5657	 Generator loss: 0.0068
# Iterations: 282	 Discriminator loss: 6.9241	 Generator loss: 0.0089
# Iterations: 283	 Discriminator loss: 7.3342	 Generator loss: 0.0119
# Iterations: 284	 Discriminator loss: 7.8066	 Generator loss: 0.0165
# Iterations: 285	 Discriminator loss: 8.2801	 Generator loss: 0.0221
# Iterations: 286	 Discriminator loss: 8.7617	 Generator loss: 0.0310
# Iterations: 287	 Discriminator loss: 9.2262	 Generator loss: 0.0430
# Iterations: 288	 Discriminator loss: 9.6140	 Generator loss: 0.0446
# Iterations: 289	 Discriminator loss: 10.4221	 Generator loss: 0.1410
# Iterations: 290	 Discriminator loss: 4.6652	 Generator loss: 0.0002
# Iterations: 291	 Discriminator loss: 9.5632	 Generator loss: 0.0357
# Iterations: 292	 Discriminator loss: 7.4257	 Generator loss: 0.0011
# Iterations: 293	 Discriminator loss: 9.9598	 Generator loss: 0.0694
# Iterations: 294	 Discriminator loss: 11.1630	 Generator loss: 0.3713
# Iterations: 295	 Discriminator loss: 11.8862	 Generator loss: 1.0169
# Iterations: 296	 Discriminator loss: 11.2071	 Generator loss: 15.9087
# Iterations: 297	 Discriminator loss: 11.7055	 Generator loss: 1.2787
# Iterations: 298	 Discriminator loss: 4.0755	 Generator loss: 2.5832
# Iterations: 299	 Discriminator loss: 6.1094	 Generator loss: 16.8635
# Iterations: 300	 Discriminator loss: 7.6844	 Generator loss: 0.0021
# Iterations: 301	 Discriminator loss: 6.8800	 Generator loss: 15.7263
# Iterations: 302	 Discriminator loss: 9.0798	 Generator loss: 0.0586
# Iterations: 303	 Discriminator loss: 3.9043	 Generator loss: 0.4451
# Iterations: 304	 Discriminator loss: 8.1922	 Generator loss: 0.0103
# Iterations: 305	 Discriminator loss: 6.3971	 Generator loss: 14.7042
# Iterations: 306	 Discriminator loss: 4.2665	 Generator loss: 10.6137
# Iterations: 307	 Discriminator loss: 7.2907	 Generator loss: 12.7629
# Iterations: 308	 Discriminator loss: 4.9347	 Generator loss: 12.0443
# Iterations: 309	 Discriminator loss: 3.6891	 Generator loss: 5.6660
# Iterations: 310	 Discriminator loss: 8.8125	 Generator loss: 10.7038
# Iterations: 311	 Discriminator loss: 3.6114	 Generator loss: 5.7827
# Iterations: 312	 Discriminator loss: 6.3523	 Generator loss: 11.3495
# Iterations: 313	 Discriminator loss: 3.7885	 Generator loss: 8.2790
# Iterations: 314	 Discriminator loss: 5.7256	 Generator loss: 10.6196
# Iterations: 315	 Discriminator loss: 3.7021	 Generator loss: 7.6816
# Iterations: 316	 Discriminator loss: 5.4211	 Generator loss: 10.3445
# Iterations: 317	 Discriminator loss: 3.8202	 Generator loss: 8.3995
# Iterations: 318	 Discriminator loss: 4.5372	 Generator loss: 9.3199
# Iterations: 319	 Discriminator loss: 3.9663	 Generator loss: 8.3621
# Iterations: 320	 Discriminator loss: 4.1652	 Generator loss: 8.4773
# Iterations: 321	 Discriminator loss: 4.1060	 Generator loss: 8.1922
# Iterations: 322	 Discriminator loss: 4.0948	 Generator loss: 8.0981
# Iterations: 323	 Discriminator loss: 4.0543	 Generator loss: 7.9471
# Iterations: 324	 Discriminator loss: 4.1690	 Generator loss: 7.7244
# Iterations: 325	 Discriminator loss: 4.2020	 Generator loss: 7.4801
# Iterations: 326	 Discriminator loss: 4.1456	 Generator loss: 7.2570
# Iterations: 327	 Discriminator loss: 4.1603	 Generator loss: 7.0720
# Iterations: 328	 Discriminator loss: 4.1964	 Generator loss: 7.0199
# Iterations: 329	 Discriminator loss: 4.2021	 Generator loss: 6.8994
# Iterations: 330	 Discriminator loss: 4.2507	 Generator loss: 6.6524
# Iterations: 331	 Discriminator loss: 4.3166	 Generator loss: 6.4108
# Iterations: 332	 Discriminator loss: 4.3043	 Generator loss: 6.2197
# Iterations: 333	 Discriminator loss: 4.2696	 Generator loss: 6.0958
# Iterations: 334	 Discriminator loss: 4.2960	 Generator loss: 6.0722
# Iterations: 335	 Discriminator loss: 4.3199	 Generator loss: 5.9738
# Iterations: 336	 Discriminator loss: 4.3707	 Generator loss: 5.7938
# Iterations: 337	 Discriminator loss: 4.4215	 Generator loss: 5.5759
# Iterations: 338	 Discriminator loss: 4.3980	 Generator loss: 5.4904
# Iterations: 339	 Discriminator loss: 4.3653	 Generator loss: 5.4275
# Iterations: 340	 Discriminator loss: 4.3783	 Generator loss: 5.4131
# Iterations: 341	 Discriminator loss: 4.4001	 Generator loss: 5.3771
# Iterations: 342	 Discriminator loss: 4.4554	 Generator loss: 5.1818
# Iterations: 343	 Discriminator loss: 4.4793	 Generator loss: 5.0553
# Iterations: 344	 Discriminator loss: 4.4227	 Generator loss: 5.0139
# Iterations: 345	 Discriminator loss: 4.4185	 Generator loss: 5.0450
# Iterations: 346	 Discriminator loss: 4.3886	 Generator loss: 5.0970
# Iterations: 347	 Discriminator loss: 4.4527	 Generator loss: 4.9828
# Iterations: 348	 Discriminator loss: 4.4765	 Generator loss: 4.7980
# Iterations: 349	 Discriminator loss: 4.4219	 Generator loss: 4.8029
# Iterations: 350	 Discriminator loss: 4.3794	 Generator loss: 4.8025
# Iterations: 351	 Discriminator loss: 4.3700	 Generator loss: 4.8942
# Iterations: 352	 Discriminator loss: 4.4123	 Generator loss: 4.7511
# Iterations: 353	 Discriminator loss: 4.4491	 Generator loss: 4.6305
# Iterations: 354	 Discriminator loss: 4.4051	 Generator loss: 4.6165
# Iterations: 355	 Discriminator loss: 4.3697	 Generator loss: 4.6609
# Iterations: 356	 Discriminator loss: 4.3718	 Generator loss: 4.6641
# Iterations: 357	 Discriminator loss: 4.3980	 Generator loss: 4.5601
# Iterations: 358	 Discriminator loss: 4.4034	 Generator loss: 4.5240
# Iterations: 359	 Discriminator loss: 4.3511	 Generator loss: 4.5228
# Iterations: 360	 Discriminator loss: 4.3349	 Generator loss: 4.5708
# Iterations: 361	 Discriminator loss: 4.3954	 Generator loss: 4.4933
# Iterations: 362	 Discriminator loss: 4.3573	 Generator loss: 4.3703
# Iterations: 363	 Discriminator loss: 4.3109	 Generator loss: 4.4107
# Iterations: 364	 Discriminator loss: 4.3311	 Generator loss: 4.4905
# Iterations: 365	 Discriminator loss: 4.3215	 Generator loss: 4.3646
# Iterations: 366	 Discriminator loss: 4.3351	 Generator loss: 4.2946
# Iterations: 367	 Discriminator loss: 4.3034	 Generator loss: 4.3060
# Iterations: 368	 Discriminator loss: 4.2977	 Generator loss: 4.3839
# Iterations: 369	 Discriminator loss: 4.3333	 Generator loss: 4.2731
# Iterations: 370	 Discriminator loss: 4.2987	 Generator loss: 4.1508
# Iterations: 371	 Discriminator loss: 4.2863	 Generator loss: 4.2755
# Iterations: 372	 Discriminator loss: 4.2630	 Generator loss: 4.2322
# Iterations: 373	 Discriminator loss: 4.2918	 Generator loss: 4.1257
# Iterations: 374	 Discriminator loss: 4.2744	 Generator loss: 4.1907
# Iterations: 375	 Discriminator loss: 4.2886	 Generator loss: 4.2056
# Iterations: 376	 Discriminator loss: 4.2729	 Generator loss: 4.0297
# Iterations: 377	 Discriminator loss: 4.2227	 Generator loss: 4.0676
# Iterations: 378	 Discriminator loss: 4.2275	 Generator loss: 4.1449
# Iterations: 379	 Discriminator loss: 4.2046	 Generator loss: 3.9901
# Iterations: 380	 Discriminator loss: 4.2058	 Generator loss: 4.0551
# Iterations: 381	 Discriminator loss: 4.2090	 Generator loss: 4.0286
# Iterations: 382	 Discriminator loss: 4.2139	 Generator loss: 3.9472
# Iterations: 383	 Discriminator loss: 4.2115	 Generator loss: 4.0139
# Iterations: 384	 Discriminator loss: 4.1906	 Generator loss: 3.8895
# Iterations: 385	 Discriminator loss: 4.2032	 Generator loss: 3.9918
# Iterations: 386	 Discriminator loss: 4.1581	 Generator loss: 3.8595
# Iterations: 387	 Discriminator loss: 4.1042	 Generator loss: 3.8550
# Iterations: 388	 Discriminator loss: 4.1419	 Generator loss: 3.9265
# Iterations: 389	 Discriminator loss: 4.1410	 Generator loss: 3.7341
# Iterations: 390	 Discriminator loss: 4.0910	 Generator loss: 3.9217
# Iterations: 391	 Discriminator loss: 4.0888	 Generator loss: 3.6490
# Iterations: 392	 Discriminator loss: 4.0915	 Generator loss: 3.9326
# Iterations: 393	 Discriminator loss: 4.1139	 Generator loss: 3.7204
# Iterations: 394	 Discriminator loss: 4.1062	 Generator loss: 3.6913
# Iterations: 395	 Discriminator loss: 4.0666	 Generator loss: 3.7557
# Iterations: 396	 Discriminator loss: 4.0664	 Generator loss: 3.7545
# Iterations: 397	 Discriminator loss: 4.0849	 Generator loss: 3.6271
# Iterations: 398	 Discriminator loss: 4.0641	 Generator loss: 3.6766
# Iterations: 399	 Discriminator loss: 4.0408	 Generator loss: 3.7180
# Iterations: 400	 Discriminator loss: 4.0457	 Generator loss: 3.6119
# Iterations: 401	 Discriminator loss: 4.0242	 Generator loss: 3.5869
# Iterations: 402	 Discriminator loss: 4.0283	 Generator loss: 3.6481
# Iterations: 403	 Discriminator loss: 4.0153	 Generator loss: 3.6104
# Iterations: 404	 Discriminator loss: 4.0192	 Generator loss: 3.5136
# Iterations: 405	 Discriminator loss: 3.9992	 Generator loss: 3.5760
# Iterations: 406	 Discriminator loss: 3.9905	 Generator loss: 3.5806
# Iterations: 407	 Discriminator loss: 3.9771	 Generator loss: 3.4819
# Iterations: 408	 Discriminator loss: 3.9742	 Generator loss: 3.5114
# Iterations: 409	 Discriminator loss: 3.9777	 Generator loss: 3.5300
# Iterations: 410	 Discriminator loss: 3.9381	 Generator loss: 3.4465
# Iterations: 411	 Discriminator loss: 3.9822	 Generator loss: 3.4696
# Iterations: 412	 Discriminator loss: 3.9217	 Generator loss: 3.3997
# Iterations: 413	 Discriminator loss: 3.9486	 Generator loss: 3.5331
# Iterations: 414	 Discriminator loss: 3.8944	 Generator loss: 3.2609
# Iterations: 415	 Discriminator loss: 3.9186	 Generator loss: 3.5527
# Iterations: 416	 Discriminator loss: 3.8792	 Generator loss: 3.2803
# Iterations: 417	 Discriminator loss: 3.9185	 Generator loss: 3.4153
# Iterations: 418	 Discriminator loss: 3.8829	 Generator loss: 3.2993
# Iterations: 419	 Discriminator loss: 3.8854	 Generator loss: 3.4255
# Iterations: 420	 Discriminator loss: 3.8630	 Generator loss: 3.2326
# Iterations: 421	 Discriminator loss: 3.8672	 Generator loss: 3.3794
# Iterations: 422	 Discriminator loss: 3.8392	 Generator loss: 3.2580
# Iterations: 423	 Discriminator loss: 3.8464	 Generator loss: 3.2716
# Iterations: 424	 Discriminator loss: 3.8482	 Generator loss: 3.3015
# Iterations: 425	 Discriminator loss: 3.8147	 Generator loss: 3.2156
# Iterations: 426	 Discriminator loss: 3.8092	 Generator loss: 3.2299
# Iterations: 427	 Discriminator loss: 3.8237	 Generator loss: 3.2812
# Iterations: 428	 Discriminator loss: 3.7798	 Generator loss: 3.1290
# Iterations: 429	 Discriminator loss: 3.8111	 Generator loss: 3.2847
# Iterations: 430	 Discriminator loss: 3.7545	 Generator loss: 3.0894
# Iterations: 431	 Discriminator loss: 3.8005	 Generator loss: 3.2638
# Iterations: 432	 Discriminator loss: 3.7310	 Generator loss: 3.0630
# Iterations: 433	 Discriminator loss: 3.7820	 Generator loss: 3.2102
# Iterations: 434	 Discriminator loss: 3.7558	 Generator loss: 3.1204
# Iterations: 435	 Discriminator loss: 3.7189	 Generator loss: 3.0583
# Iterations: 436	 Discriminator loss: 3.7596	 Generator loss: 3.2091
# Iterations: 437	 Discriminator loss: 3.6156	 Generator loss: 2.8258
# Iterations: 438	 Discriminator loss: 3.7367	 Generator loss: 3.3138
# Iterations: 439	 Discriminator loss: 3.6238	 Generator loss: 2.8753
# Iterations: 440	 Discriminator loss: 3.6858	 Generator loss: 3.0783
# Iterations: 441	 Discriminator loss: 3.6849	 Generator loss: 3.0854
# Iterations: 442	 Discriminator loss: 3.6482	 Generator loss: 2.9931
# Iterations: 443	 Discriminator loss: 3.6713	 Generator loss: 2.9956
# Iterations: 444	 Discriminator loss: 3.6353	 Generator loss: 2.9749
# Iterations: 445	 Discriminator loss: 3.6472	 Generator loss: 3.0459
# Iterations: 446	 Discriminator loss: 3.6174	 Generator loss: 2.9390
# Iterations: 447	 Discriminator loss: 3.6344	 Generator loss: 2.9693
# Iterations: 448	 Discriminator loss: 3.6155	 Generator loss: 2.9371
# Iterations: 449	 Discriminator loss: 3.5971	 Generator loss: 2.9644
# Iterations: 450	 Discriminator loss: 3.5768	 Generator loss: 2.8951
# Iterations: 451	 Discriminator loss: 3.5740	 Generator loss: 2.9112
# Iterations: 452	 Discriminator loss: 3.5986	 Generator loss: 2.9572
# Iterations: 453	 Discriminator loss: 3.5444	 Generator loss: 2.8602
# Iterations: 454	 Discriminator loss: 3.5640	 Generator loss: 2.8852
# Iterations: 455	 Discriminator loss: 3.5179	 Generator loss: 2.8236
# Iterations: 456	 Discriminator loss: 3.5667	 Generator loss: 2.9215
# Iterations: 457	 Discriminator loss: 3.5046	 Generator loss: 2.8087
# Iterations: 458	 Discriminator loss: 3.5310	 Generator loss: 2.8567
# Iterations: 459	 Discriminator loss: 3.4999	 Generator loss: 2.7998
# Iterations: 460	 Discriminator loss: 3.5000	 Generator loss: 2.8451
# Iterations: 461	 Discriminator loss: 3.4996	 Generator loss: 2.8094
# Iterations: 462	 Discriminator loss: 3.4687	 Generator loss: 2.7537
# Iterations: 463	 Discriminator loss: 3.4826	 Generator loss: 2.8204
# Iterations: 464	 Discriminator loss: 3.4487	 Generator loss: 2.7475
# Iterations: 465	 Discriminator loss: 3.4556	 Generator loss: 2.7614
# Iterations: 466	 Discriminator loss: 3.4581	 Generator loss: 2.7808
# Iterations: 467	 Discriminator loss: 3.4229	 Generator loss: 2.7167
# Iterations: 468	 Discriminator loss: 3.4307	 Generator loss: 2.7329
# Iterations: 469	 Discriminator loss: 3.4223	 Generator loss: 2.7385
# Iterations: 470	 Discriminator loss: 3.3913	 Generator loss: 2.6840
# Iterations: 471	 Discriminator loss: 3.4196	 Generator loss: 2.7328
# Iterations: 472	 Discriminator loss: 3.3629	 Generator loss: 2.6522
# Iterations: 473	 Discriminator loss: 3.4079	 Generator loss: 2.7213
# Iterations: 474	 Discriminator loss: 3.3533	 Generator loss: 2.6380
# Iterations: 475	 Discriminator loss: 3.3855	 Generator loss: 2.6936
# Iterations: 476	 Discriminator loss: 3.3261	 Generator loss: 2.5937
# Iterations: 477	 Discriminator loss: 3.3941	 Generator loss: 2.7220
# Iterations: 478	 Discriminator loss: 3.2312	 Generator loss: 2.4587
# Iterations: 479	 Discriminator loss: 3.4258	 Generator loss: 2.8054
# Iterations: 480	 Discriminator loss: 3.2188	 Generator loss: 2.4718
# Iterations: 481	 Discriminator loss: 3.3504	 Generator loss: 2.6572
# Iterations: 482	 Discriminator loss: 3.3028	 Generator loss: 2.6025
# Iterations: 483	 Discriminator loss: 3.2765	 Generator loss: 2.5643
# Iterations: 484	 Discriminator loss: 3.2877	 Generator loss: 2.5736
# Iterations: 485	 Discriminator loss: 3.2723	 Generator loss: 2.5775
# Iterations: 486	 Discriminator loss: 3.2642	 Generator loss: 2.5580
# Iterations: 487	 Discriminator loss: 3.2572	 Generator loss: 2.5443
# Iterations: 488	 Discriminator loss: 3.2582	 Generator loss: 2.5684
# Iterations: 489	 Discriminator loss: 3.2135	 Generator loss: 2.4975
# Iterations: 490	 Discriminator loss: 3.2327	 Generator loss: 2.5275
# Iterations: 491	 Discriminator loss: 3.2351	 Generator loss: 2.5427
# Iterations: 492	 Discriminator loss: 3.1814	 Generator loss: 2.4618
# Iterations: 493	 Discriminator loss: 3.2167	 Generator loss: 2.5313
# Iterations: 494	 Discriminator loss: 3.1821	 Generator loss: 2.4823
# Iterations: 495	 Discriminator loss: 3.1889	 Generator loss: 2.4799
# Iterations: 496	 Discriminator loss: 3.1594	 Generator loss: 2.4622
# Iterations: 497	 Discriminator loss: 3.1623	 Generator loss: 2.4547
# Iterations: 498	 Discriminator loss: 3.1819	 Generator loss: 2.4898
# Iterations: 499	 Discriminator loss: 3.0978	 Generator loss: 2.3907
# Iterations: 500	 Discriminator loss: 3.1840	 Generator loss: 2.4948
# Iterations: 501	 Discriminator loss: 3.0996	 Generator loss: 2.4114
# Iterations: 502	 Discriminator loss: 3.1066	 Generator loss: 2.4003
# Iterations: 503	 Discriminator loss: 3.1308	 Generator loss: 2.4513
# Iterations: 504	 Discriminator loss: 3.0536	 Generator loss: 2.3440
# Iterations: 505	 Discriminator loss: 3.1548	 Generator loss: 2.4807
# Iterations: 506	 Discriminator loss: 3.0141	 Generator loss: 2.3206
# Iterations: 507	 Discriminator loss: 3.1272	 Generator loss: 2.4435
# Iterations: 508	 Discriminator loss: 3.0370	 Generator loss: 2.3455
# Iterations: 509	 Discriminator loss: 3.0594	 Generator loss: 2.3623
# Iterations: 510	 Discriminator loss: 3.0691	 Generator loss: 2.3871
# Iterations: 511	 Discriminator loss: 2.9860	 Generator loss: 2.2449
# Iterations: 512	 Discriminator loss: 3.0932	 Generator loss: 2.4397
# Iterations: 513	 Discriminator loss: 2.9466	 Generator loss: 2.2633
# Iterations: 514	 Discriminator loss: 3.0525	 Generator loss: 2.3554
# Iterations: 515	 Discriminator loss: 2.9752	 Generator loss: 2.3025
# Iterations: 516	 Discriminator loss: 2.9983	 Generator loss: 2.3216
# Iterations: 517	 Discriminator loss: 2.9650	 Generator loss: 2.2696
# Iterations: 518	 Discriminator loss: 3.0135	 Generator loss: 2.3390
# Iterations: 519	 Discriminator loss: 2.9273	 Generator loss: 2.2584
# Iterations: 520	 Discriminator loss: 2.9700	 Generator loss: 2.3012
# Iterations: 521	 Discriminator loss: 2.9537	 Generator loss: 2.2629
# Iterations: 522	 Discriminator loss: 2.9578	 Generator loss: 2.3005
# Iterations: 523	 Discriminator loss: 2.8911	 Generator loss: 2.2205
# Iterations: 524	 Discriminator loss: 2.9625	 Generator loss: 2.3040
# Iterations: 525	 Discriminator loss: 2.8911	 Generator loss: 2.2218
# Iterations: 526	 Discriminator loss: 2.9137	 Generator loss: 2.2568
# Iterations: 527	 Discriminator loss: 2.8636	 Generator loss: 2.2032
# Iterations: 528	 Discriminator loss: 2.9160	 Generator loss: 2.2534
# Iterations: 529	 Discriminator loss: 2.8754	 Generator loss: 2.2341
# Iterations: 530	 Discriminator loss: 2.8375	 Generator loss: 2.1823
# Iterations: 531	 Discriminator loss: 2.8966	 Generator loss: 2.2402
# Iterations: 532	 Discriminator loss: 2.8282	 Generator loss: 2.1806
# Iterations: 533	 Discriminator loss: 2.8468	 Generator loss: 2.1982
# Iterations: 534	 Discriminator loss: 2.8513	 Generator loss: 2.2105
# Iterations: 535	 Discriminator loss: 2.7998	 Generator loss: 2.1518
# Iterations: 536	 Discriminator loss: 2.8339	 Generator loss: 2.1904
# Iterations: 537	 Discriminator loss: 2.7935	 Generator loss: 2.1517
# Iterations: 538	 Discriminator loss: 2.8177	 Generator loss: 2.1855
# Iterations: 539	 Discriminator loss: 2.7798	 Generator loss: 2.1443
# Iterations: 540	 Discriminator loss: 2.7550	 Generator loss: 2.1384
# Iterations: 541	 Discriminator loss: 2.7768	 Generator loss: 2.1505
# Iterations: 542	 Discriminator loss: 2.7691	 Generator loss: 2.1348
# Iterations: 543	 Discriminator loss: 2.7331	 Generator loss: 2.1133
# Iterations: 544	 Discriminator loss: 2.7600	 Generator loss: 2.1211
# Iterations: 545	 Discriminator loss: 2.7553	 Generator loss: 2.1355
# Iterations: 546	 Discriminator loss: 2.6850	 Generator loss: 2.0671
# Iterations: 547	 Discriminator loss: 2.7737	 Generator loss: 2.1584
# Iterations: 548	 Discriminator loss: 2.6408	 Generator loss: 2.0229
# Iterations: 549	 Discriminator loss: 2.7601	 Generator loss: 2.1491
# Iterations: 550	 Discriminator loss: 2.6670	 Generator loss: 2.0754
# Iterations: 551	 Discriminator loss: 2.6639	 Generator loss: 2.0674
# Iterations: 552	 Discriminator loss: 2.6847	 Generator loss: 2.0776
# Iterations: 553	 Discriminator loss: 2.6693	 Generator loss: 2.0865
# Iterations: 554	 Discriminator loss: 2.6037	 Generator loss: 1.9962
# Iterations: 555	 Discriminator loss: 2.6851	 Generator loss: 2.0792
# Iterations: 556	 Discriminator loss: 2.5828	 Generator loss: 1.9767
# Iterations: 557	 Discriminator loss: 2.7031	 Generator loss: 2.1116
# Iterations: 558	 Discriminator loss: 2.5210	 Generator loss: 1.9437
# Iterations: 559	 Discriminator loss: 2.6541	 Generator loss: 2.0689
# Iterations: 560	 Discriminator loss: 2.5885	 Generator loss: 1.9970
# Iterations: 561	 Discriminator loss: 2.5923	 Generator loss: 2.0292
# Iterations: 562	 Discriminator loss: 2.5257	 Generator loss: 1.9929
# Iterations: 563	 Discriminator loss: 2.3874	 Generator loss: 1.8834
# Iterations: 564	 Discriminator loss: 2.4600	 Generator loss: 2.0020
# Iterations: 565	 Discriminator loss: 2.4294	 Generator loss: 1.8806
# Iterations: 566	 Discriminator loss: 2.4096	 Generator loss: 1.9265
# Iterations: 567	 Discriminator loss: 2.4244	 Generator loss: 1.9373
# Iterations: 568	 Discriminator loss: 2.4339	 Generator loss: 2.0081
# Iterations: 569	 Discriminator loss: 2.3478	 Generator loss: 1.8798
# Iterations: 570	 Discriminator loss: 2.3861	 Generator loss: 1.8806
# Iterations: 571	 Discriminator loss: 2.3846	 Generator loss: 1.9007
# Iterations: 572	 Discriminator loss: 2.3875	 Generator loss: 1.9101
# Iterations: 573	 Discriminator loss: 2.4256	 Generator loss: 1.9953
# Iterations: 574	 Discriminator loss: 2.3181	 Generator loss: 1.8153
# Iterations: 575	 Discriminator loss: 2.4359	 Generator loss: 1.8853
# Iterations: 576	 Discriminator loss: 2.3923	 Generator loss: 1.9602
# Iterations: 577	 Discriminator loss: 2.2935	 Generator loss: 1.8489
# Iterations: 578	 Discriminator loss: 2.3773	 Generator loss: 1.9502
# Iterations: 579	 Discriminator loss: 2.2835	 Generator loss: 1.7828
# Iterations: 580	 Discriminator loss: 2.3638	 Generator loss: 1.8740
# Iterations: 581	 Discriminator loss: 2.3465	 Generator loss: 1.8699
# Iterations: 582	 Discriminator loss: 2.3277	 Generator loss: 1.8608
# Iterations: 583	 Discriminator loss: 2.3662	 Generator loss: 1.9456
# Iterations: 584	 Discriminator loss: 2.2501	 Generator loss: 1.7854
# Iterations: 585	 Discriminator loss: 2.3095	 Generator loss: 1.8373
# Iterations: 586	 Discriminator loss: 2.3316	 Generator loss: 1.8457
# Iterations: 587	 Discriminator loss: 2.3677	 Generator loss: 1.9513
# Iterations: 588	 Discriminator loss: 2.1976	 Generator loss: 1.7377
# Iterations: 589	 Discriminator loss: 2.2953	 Generator loss: 1.8442
# Iterations: 590	 Discriminator loss: 2.2775	 Generator loss: 1.8470
# Iterations: 591	 Discriminator loss: 2.3490	 Generator loss: 1.9427
# Iterations: 592	 Discriminator loss: 2.1424	 Generator loss: 1.6977
# Iterations: 593	 Discriminator loss: 2.2572	 Generator loss: 1.8027
# Iterations: 594	 Discriminator loss: 2.2484	 Generator loss: 1.9204
# Iterations: 595	 Discriminator loss: 2.2849	 Generator loss: 1.7531
# Iterations: 596	 Discriminator loss: 2.2134	 Generator loss: 1.7737
# Iterations: 597	 Discriminator loss: 2.2209	 Generator loss: 1.8132
# Iterations: 598	 Discriminator loss: 2.2644	 Generator loss: 1.9819
# Iterations: 599	 Discriminator loss: 2.1054	 Generator loss: 1.6570
# Iterations: 600	 Discriminator loss: 2.1729	 Generator loss: 1.7551
# Iterations: 601	 Discriminator loss: 2.2222	 Generator loss: 1.8895
# Iterations: 602	 Discriminator loss: 2.1278	 Generator loss: 1.8605
# Iterations: 603	 Discriminator loss: 2.0851	 Generator loss: 1.6567
# Iterations: 604	 Discriminator loss: 2.2264	 Generator loss: 1.7187
# Iterations: 605	 Discriminator loss: 2.1970	 Generator loss: 1.9123
# Iterations: 606	 Discriminator loss: 2.1336	 Generator loss: 1.8913
# Iterations: 607	 Discriminator loss: 2.0598	 Generator loss: 1.9126
# Iterations: 608	 Discriminator loss: 1.9455	 Generator loss: 1.5558
# Iterations: 609	 Discriminator loss: 2.1521	 Generator loss: 1.7213
# Iterations: 610	 Discriminator loss: 2.0713	 Generator loss: 1.9443
# Iterations: 611	 Discriminator loss: 2.0017	 Generator loss: 1.6049
# Iterations: 612	 Discriminator loss: 2.0948	 Generator loss: 1.7758
# Iterations: 613	 Discriminator loss: 1.9923	 Generator loss: 1.7767
# Iterations: 614	 Discriminator loss: 2.0309	 Generator loss: 1.7943
# Iterations: 615	 Discriminator loss: 2.0594	 Generator loss: 1.8035
# Iterations: 616	 Discriminator loss: 1.9175	 Generator loss: 1.6727
# Iterations: 617	 Discriminator loss: 1.9467	 Generator loss: 1.7479
# Iterations: 618	 Discriminator loss: 1.9653	 Generator loss: 1.5623
# Iterations: 619	 Discriminator loss: 1.9624	 Generator loss: 1.8418
# Iterations: 620	 Discriminator loss: 1.8409	 Generator loss: 1.7788
# Iterations: 621	 Discriminator loss: 2.0552	 Generator loss: 1.6374
# Iterations: 622	 Discriminator loss: 1.8306	 Generator loss: 1.8298
# Iterations: 623	 Discriminator loss: 1.9449	 Generator loss: 1.6864
# Iterations: 624	 Discriminator loss: 1.8928	 Generator loss: 1.4708
# Iterations: 625	 Discriminator loss: 1.8513	 Generator loss: 1.7561
# Iterations: 626	 Discriminator loss: 1.8944	 Generator loss: 1.6211
# Iterations: 627	 Discriminator loss: 1.8443	 Generator loss: 1.8586
# Iterations: 628	 Discriminator loss: 1.8677	 Generator loss: 2.0507
# Iterations: 629	 Discriminator loss: 1.8150	 Generator loss: 2.0437
# Iterations: 630	 Discriminator loss: 1.4858	 Generator loss: 1.9473
# Iterations: 631	 Discriminator loss: 1.6108	 Generator loss: 1.6801
# Iterations: 632	 Discriminator loss: 1.5474	 Generator loss: 1.6460
# Iterations: 633	 Discriminator loss: 1.6477	 Generator loss: 1.6387
# Iterations: 634	 Discriminator loss: 1.7804	 Generator loss: 1.6509
# Iterations: 635	 Discriminator loss: 1.7423	 Generator loss: 1.7797
# Iterations: 636	 Discriminator loss: 1.7019	 Generator loss: 1.9791
# Iterations: 637	 Discriminator loss: 1.6813	 Generator loss: 1.9007
# Iterations: 638	 Discriminator loss: 1.5956	 Generator loss: 1.7357
# Iterations: 639	 Discriminator loss: 1.4167	 Generator loss: 1.8662
# Iterations: 640	 Discriminator loss: 1.5048	 Generator loss: 1.9028
# Iterations: 641	 Discriminator loss: 1.4741	 Generator loss: 1.6971
# Iterations: 642	 Discriminator loss: 1.6202	 Generator loss: 1.6567
# Iterations: 643	 Discriminator loss: 1.6730	 Generator loss: 1.7327
# Iterations: 644	 Discriminator loss: 1.6418	 Generator loss: 1.7968
# Iterations: 645	 Discriminator loss: 1.5317	 Generator loss: 2.0553
# Iterations: 646	 Discriminator loss: 1.5420	 Generator loss: 1.7142
# Iterations: 647	 Discriminator loss: 1.5601	 Generator loss: 1.7539
# Iterations: 648	 Discriminator loss: 1.5689	 Generator loss: 1.8977
# Iterations: 649	 Discriminator loss: 1.5541	 Generator loss: 1.7839
# Iterations: 650	 Discriminator loss: 1.5074	 Generator loss: 1.9132
# Iterations: 651	 Discriminator loss: 1.3757	 Generator loss: 1.8981
# Iterations: 652	 Discriminator loss: 1.4013	 Generator loss: 1.9400
# Iterations: 653	 Discriminator loss: 1.4293	 Generator loss: 0.3780
# Iterations: 654	 Discriminator loss: 1.3273	 Generator loss: 0.2838
# Iterations: 655	 Discriminator loss: 1.2522	 Generator loss: 0.2189
# Iterations: 656	 Discriminator loss: 0.9799	 Generator loss: 0.3528
# Iterations: 657	 Discriminator loss: 0.8556	 Generator loss: 0.9754
# Iterations: 658	 Discriminator loss: 0.8897	 Generator loss: 0.9411
# Iterations: 659	 Discriminator loss: 1.3583	 Generator loss: 0.2849
# Iterations: 660	 Discriminator loss: 1.7015	 Generator loss: 0.1974
# Iterations: 661	 Discriminator loss: 1.7239	 Generator loss: 0.1772
# Iterations: 662	 Discriminator loss: 1.7899	 Generator loss: 0.1635
# Iterations: 663	 Discriminator loss: 1.7426	 Generator loss: 0.1749
# Iterations: 664	 Discriminator loss: 1.5731	 Generator loss: 0.1828
# Iterations: 665	 Discriminator loss: 1.5876	 Generator loss: 0.2279
# Iterations: 666	 Discriminator loss: 1.6257	 Generator loss: 0.2132
# Iterations: 667	 Discriminator loss: 1.7760	 Generator loss: 0.1977
# Iterations: 668	 Discriminator loss: 1.7419	 Generator loss: 0.2138
# Iterations: 669	 Discriminator loss: 1.8543	 Generator loss: 0.2173
# Iterations: 670	 Discriminator loss: 1.7706	 Generator loss: 0.2301
# Iterations: 671	 Discriminator loss: 1.7913	 Generator loss: 0.2558
# Iterations: 672	 Discriminator loss: 1.8467	 Generator loss: 0.2525
# Iterations: 673	 Discriminator loss: 1.7487	 Generator loss: 0.2364
# Iterations: 674	 Discriminator loss: 1.7138	 Generator loss: 0.2669
# Iterations: 675	 Discriminator loss: 1.9503	 Generator loss: 0.3041
# Iterations: 676	 Discriminator loss: 1.7581	 Generator loss: 0.2693
# Iterations: 677	 Discriminator loss: 1.8136	 Generator loss: 0.2745
# Iterations: 678	 Discriminator loss: 1.8449	 Generator loss: 0.2896
# Iterations: 679	 Discriminator loss: 1.8407	 Generator loss: 0.2839
# Iterations: 680	 Discriminator loss: 1.8382	 Generator loss: 0.2814
# Iterations: 681	 Discriminator loss: 2.0117	 Generator loss: 0.3155
# Iterations: 682	 Discriminator loss: 1.9569	 Generator loss: 0.2953
# Iterations: 683	 Discriminator loss: 1.9507	 Generator loss: 0.2970
# Iterations: 684	 Discriminator loss: 2.0478	 Generator loss: 0.3216
# Iterations: 685	 Discriminator loss: 1.9518	 Generator loss: 0.3090
# Iterations: 686	 Discriminator loss: 1.9967	 Generator loss: 0.3237
# Iterations: 687	 Discriminator loss: 1.9765	 Generator loss: 0.3117
# Iterations: 688	 Discriminator loss: 2.0913	 Generator loss: 0.3141
# Iterations: 689	 Discriminator loss: 2.1037	 Generator loss: 0.3143
# Iterations: 690	 Discriminator loss: 2.0619	 Generator loss: 0.3185
# Iterations: 691	 Discriminator loss: 2.1332	 Generator loss: 0.3436
# Iterations: 692	 Discriminator loss: 2.0350	 Generator loss: 0.3273
# Iterations: 693	 Discriminator loss: 2.1530	 Generator loss: 0.3494
# Iterations: 694	 Discriminator loss: 2.0880	 Generator loss: 0.3412
# Iterations: 695	 Discriminator loss: 2.1236	 Generator loss: 0.3341
# Iterations: 696	 Discriminator loss: 2.2377	 Generator loss: 0.3743
# Iterations: 697	 Discriminator loss: 2.1991	 Generator loss: 0.3432
# Iterations: 698	 Discriminator loss: 2.2606	 Generator loss: 0.3908
# Iterations: 699	 Discriminator loss: 2.1188	 Generator loss: 0.3707
# Iterations: 700	 Discriminator loss: 2.1288	 Generator loss: 0.3509
# Iterations: 701	 Discriminator loss: 2.3333	 Generator loss: 0.4008
# Iterations: 702	 Discriminator loss: 2.3063	 Generator loss: 0.3961
# Iterations: 703	 Discriminator loss: 2.2457	 Generator loss: 0.3887
# Iterations: 704	 Discriminator loss: 2.1584	 Generator loss: 0.3818
# Iterations: 705	 Discriminator loss: 2.5839	 Generator loss: 0.5585
# Iterations: 706	 Discriminator loss: 2.0414	 Generator loss: 0.3141
# ...
# Iterations: 34773	 Discriminator loss: 0.7620	 Generator loss: 0.2947
# Iterations: 34774	 Discriminator loss: 1.2829	 Generator loss: 0.2652
# Iterations: 34775	 Discriminator loss: 1.3753	 Generator loss: 0.5398
# Iterations: 34776	 Discriminator loss: 1.1405	 Generator loss: 0.4425
# Iterations: 34777	 Discriminator loss: 1.3167	 Generator loss: 0.5816
# Iterations: 34778	 Discriminator loss: 1.2960	 Generator loss: 0.3984
# Iterations: 34779	 Discriminator loss: 1.3004	 Generator loss: 0.4463
# Iterations: 34780	 Discriminator loss: 0.9533	 Generator loss: 0.2936
# Iterations: 34781	 Discriminator loss: 0.8543	 Generator loss: 0.2919
# Iterations: 34782	 Discriminator loss: 1.1069	 Generator loss: 0.3964
# Iterations: 34783	 Discriminator loss: 0.8818	 Generator loss: 0.3277
# Iterations: 34784	 Discriminator loss: 1.1727	 Generator loss: 0.3953
# Iterations: 34785	 Discriminator loss: 1.0119	 Generator loss: 0.2511
# Iterations: 34786	 Discriminator loss: 1.2771	 Generator loss: 0.4343
# Iterations: 34787	 Discriminator loss: 1.1629	 Generator loss: 0.2779
# Iterations: 34788	 Discriminator loss: 1.3016	 Generator loss: 0.4575
# Iterations: 34789	 Discriminator loss: 0.9756	 Generator loss: 0.3466
# Iterations: 34790	 Discriminator loss: 1.1377	 Generator loss: 0.3173
# Iterations: 34791	 Discriminator loss: 0.7246	 Generator loss: 0.2814
# Iterations: 34792	 Discriminator loss: 0.7868	 Generator loss: 0.2272
# Iterations: 34793	 Discriminator loss: 1.5941	 Generator loss: 0.3216
# Iterations: 34794	 Discriminator loss: 1.3551	 Generator loss: 0.5328
# Iterations: 34795	 Discriminator loss: 1.1583	 Generator loss: 0.2843
# Iterations: 34796	 Discriminator loss: 1.3450	 Generator loss: 0.5782
# Iterations: 34797	 Discriminator loss: 1.0550	 Generator loss: 0.4080
# Iterations: 34798	 Discriminator loss: 0.9858	 Generator loss: 0.3722
# Iterations: 34799	 Discriminator loss: 1.0149	 Generator loss: 0.2940
# Iterations: 34800	 Discriminator loss: 0.8882	 Generator loss: 0.2790
# Iterations: 34801	 Discriminator loss: 1.2488	 Generator loss: 0.5144
# Iterations: 34802	 Discriminator loss: 1.2468	 Generator loss: 0.4959
# Iterations: 34803	 Discriminator loss: 1.1095	 Generator loss: 0.3071
# Iterations: 34804	 Discriminator loss: 1.0705	 Generator loss: 0.3136
# Iterations: 34805	 Discriminator loss: 0.7955	 Generator loss: 0.2634
# Iterations: 34806	 Discriminator loss: 1.1474	 Generator loss: 0.2538
# Iterations: 34807	 Discriminator loss: 1.3136	 Generator loss: 0.5352
# Iterations: 34808	 Discriminator loss: 0.9875	 Generator loss: 0.3164
# Iterations: 34809	 Discriminator loss: 0.8595	 Generator loss: 0.2700
# Iterations: 34810	 Discriminator loss: 1.2009	 Generator loss: 0.4927
# Iterations: 34811	 Discriminator loss: 1.0745	 Generator loss: 0.3672
# Iterations: 34812	 Discriminator loss: 1.1105	 Generator loss: 0.3672
# Iterations: 34813	 Discriminator loss: 0.8814	 Generator loss: 0.3055
# Iterations: 34814	 Discriminator loss: 0.8467	 Generator loss: 0.2892
# Iterations: 34815	 Discriminator loss: 1.1380	 Generator loss: 0.2684
# Iterations: 34816	 Discriminator loss: 1.3454	 Generator loss: 0.5292
# Iterations: 34817	 Discriminator loss: 1.2794	 Generator loss: 0.4296
# Iterations: 34818	 Discriminator loss: 0.9750	 Generator loss: 0.4084
# Iterations: 34819	 Discriminator loss: 0.8332	 Generator loss: 0.2766
# Iterations: 34820	 Discriminator loss: 1.0343	 Generator loss: 0.2369
# Iterations: 34821	 Discriminator loss: 1.3448	 Generator loss: 0.5459
# Iterations: 34822	 Discriminator loss: 1.2586	 Generator loss: 0.5589
# Iterations: 34823	 Discriminator loss: 1.2841	 Generator loss: 0.4244
# Iterations: 34824	 Discriminator loss: 1.0170	 Generator loss: 0.3806
# Iterations: 34825	 Discriminator loss: 0.8100	 Generator loss: 0.2518
# Iterations: 34826	 Discriminator loss: 0.8553	 Generator loss: 0.2824
# Iterations: 34827	 Discriminator loss: 1.0676	 Generator loss: 0.3724
# Iterations: 34828	 Discriminator loss: 0.8756	 Generator loss: 0.3361
# Iterations: 34829	 Discriminator loss: 0.9722	 Generator loss: 0.3163
# Iterations: 34830	 Discriminator loss: 0.9398	 Generator loss: 0.3343
# Iterations: 34831	 Discriminator loss: 0.7934	 Generator loss: 0.2799
# Iterations: 34832	 Discriminator loss: 0.9254	 Generator loss: 0.3326
# Iterations: 34833	 Discriminator loss: 1.0908	 Generator loss: 0.3215
# Iterations: 34834	 Discriminator loss: 1.0445	 Generator loss: 0.3349
# Iterations: 34835	 Discriminator loss: 0.7691	 Generator loss: 0.2744
# Iterations: 34836	 Discriminator loss: 0.9532	 Generator loss: 0.3246
# Iterations: 34837	 Discriminator loss: 1.1750	 Generator loss: 0.3497
# Iterations: 34838	 Discriminator loss: 0.9943	 Generator loss: 0.3127
# Iterations: 34839	 Discriminator loss: 0.7956	 Generator loss: 0.2779
# Iterations: 34840	 Discriminator loss: 1.0603	 Generator loss: 0.3096
# Iterations: 34841	 Discriminator loss: 1.2689	 Generator loss: 0.3600
# Iterations: 34842	 Discriminator loss: 1.2343	 Generator loss: 0.4129
# Iterations: 34843	 Discriminator loss: 1.1112	 Generator loss: 0.3357
# Iterations: 34844	 Discriminator loss: 1.0977	 Generator loss: 0.3251
# Iterations: 34845	 Discriminator loss: 0.7301	 Generator loss: 0.2672
# Iterations: 34846	 Discriminator loss: 1.0775	 Generator loss: 0.3003
# Iterations: 34847	 Discriminator loss: 1.2505	 Generator loss: 0.4560
# Iterations: 34848	 Discriminator loss: 1.5080	 Generator loss: 0.3394
# Iterations: 34849	 Discriminator loss: 1.3898	 Generator loss: 0.3407
# Iterations: 34850	 Discriminator loss: 1.3801	 Generator loss: 0.6390
# Iterations: 34851	 Discriminator loss: 1.2282	 Generator loss: 0.3721
# Iterations: 34852	 Discriminator loss: 1.2426	 Generator loss: 0.4736
# Iterations: 34853	 Discriminator loss: 0.9931	 Generator loss: 0.3236
# Iterations: 34854	 Discriminator loss: 1.0017	 Generator loss: 0.2564
# Iterations: 34855	 Discriminator loss: 1.2588	 Generator loss: 0.5191
# Iterations: 34856	 Discriminator loss: 1.2581	 Generator loss: 0.4837
# Iterations: 34857	 Discriminator loss: 1.0088	 Generator loss: 0.2732
# Iterations: 34858	 Discriminator loss: 1.0846	 Generator loss: 0.3070
# Iterations: 34859	 Discriminator loss: 0.7412	 Generator loss: 0.2581
# Iterations: 34860	 Discriminator loss: 1.2538	 Generator loss: 0.2310
# Iterations: 34861	 Discriminator loss: 1.3235	 Generator loss: 0.4628
# Iterations: 34862	 Discriminator loss: 0.8919	 Generator loss: 0.2682
# Iterations: 34863	 Discriminator loss: 1.2688	 Generator loss: 0.5061
# Iterations: 34864	 Discriminator loss: 1.2341	 Generator loss: 0.2890
# Iterations: 34865	 Discriminator loss: 1.4201	 Generator loss: 0.6024
# Iterations: 34866	 Discriminator loss: 1.2508	 Generator loss: 0.3495
# Iterations: 34867	 Discriminator loss: 1.2178	 Generator loss: 0.4446
# Iterations: 34868	 Discriminator loss: 1.0852	 Generator loss: 0.3370
# Iterations: 34869	 Discriminator loss: 1.2717	 Generator loss: 0.5150
# Iterations: 34870	 Discriminator loss: 1.1100	 Generator loss: 0.3586
# Iterations: 34871	 Discriminator loss: 1.1834	 Generator loss: 0.3774
# Iterations: 34872	 Discriminator loss: 0.9550	 Generator loss: 0.3065
# Iterations: 34873	 Discriminator loss: 1.2583	 Generator loss: 0.3217
# Iterations: 34874	 Discriminator loss: 0.8266	 Generator loss: 0.2632
# Iterations: 34875	 Discriminator loss: 1.3803	 Generator loss: 0.4072
# Iterations: 34876	 Discriminator loss: 1.0925	 Generator loss: 0.3127
# Iterations: 34877	 Discriminator loss: 1.0737	 Generator loss: 0.3197
# Iterations: 34878	 Discriminator loss: 0.8272	 Generator loss: 0.2683
# Iterations: 34879	 Discriminator loss: 1.0661	 Generator loss: 0.2673
# Iterations: 34880	 Discriminator loss: 1.2339	 Generator loss: 0.5060
# Iterations: 34881	 Discriminator loss: 1.2144	 Generator loss: 0.3996
# Iterations: 34882	 Discriminator loss: 0.8255	 Generator loss: 0.2691
# Iterations: 34883	 Discriminator loss: 1.0414	 Generator loss: 0.3778
# Iterations: 34884	 Discriminator loss: 0.8386	 Generator loss: 0.2764
# Iterations: 34885	 Discriminator loss: 1.1109	 Generator loss: 0.2571
# Iterations: 34886	 Discriminator loss: 1.3959	 Generator loss: 0.4970
# Iterations: 34887	 Discriminator loss: 1.2707	 Generator loss: 0.2901
# Iterations: 34888	 Discriminator loss: 1.3591	 Generator loss: 0.5530
# Iterations: 34889	 Discriminator loss: 1.2376	 Generator loss: 0.5357
# Iterations: 34890	 Discriminator loss: 1.2835	 Generator loss: 0.4527
# Iterations: 34891	 Discriminator loss: 0.9798	 Generator loss: 0.3041
# Iterations: 34892	 Discriminator loss: 0.8193	 Generator loss: 0.3005
# Iterations: 34893	 Discriminator loss: 1.1012	 Generator loss: 0.3838
# Iterations: 34894	 Discriminator loss: 0.9281	 Generator loss: 0.3306
# Iterations: 34895	 Discriminator loss: 1.0668	 Generator loss: 0.2778
# Iterations: 34896	 Discriminator loss: 1.3497	 Generator loss: 0.4157
# Iterations: 34897	 Discriminator loss: 1.1512	 Generator loss: 0.3326
# Iterations: 34898	 Discriminator loss: 1.0724	 Generator loss: 0.3192
# Iterations: 34899	 Discriminator loss: 0.7627	 Generator loss: 0.2613
# Iterations: 34900	 Discriminator loss: 1.2605	 Generator loss: 0.3824
# Iterations: 34901	 Discriminator loss: 0.6188	 Generator loss: 0.2450
# Iterations: 34902	 Discriminator loss: 1.1698	 Generator loss: 0.2456
# Iterations: 34903	 Discriminator loss: 1.2391	 Generator loss: 0.3572
# Iterations: 34904	 Discriminator loss: 1.1734	 Generator loss: 0.4067
# Iterations: 34905	 Discriminator loss: 0.9566	 Generator loss: 0.2737
# Iterations: 34906	 Discriminator loss: 1.1481	 Generator loss: 0.3362
# Iterations: 34907	 Discriminator loss: 0.7502	 Generator loss: 0.2535
# Iterations: 34908	 Discriminator loss: 1.0988	 Generator loss: 0.2599
# Iterations: 34909	 Discriminator loss: 1.4137	 Generator loss: 0.5296
# Iterations: 34910	 Discriminator loss: 1.0134	 Generator loss: 0.3425
# Iterations: 34911	 Discriminator loss: 0.8466	 Generator loss: 0.2631
# Iterations: 34912	 Discriminator loss: 1.2126	 Generator loss: 0.4619
# Iterations: 34913	 Discriminator loss: 1.5420	 Generator loss: 0.2001
# Iterations: 34914	 Discriminator loss: 1.3938	 Generator loss: 0.4226
# Iterations: 34915	 Discriminator loss: 0.9324	 Generator loss: 0.3305
# Iterations: 34916	 Discriminator loss: 1.3073	 Generator loss: 0.2415
# Iterations: 34917	 Discriminator loss: 1.2987	 Generator loss: 0.4564
# Iterations: 34918	 Discriminator loss: 0.9509	 Generator loss: 0.2752
# Iterations: 34919	 Discriminator loss: 1.2759	 Generator loss: 0.5304
# Iterations: 34920	 Discriminator loss: 1.1095	 Generator loss: 0.4588
# Iterations: 34921	 Discriminator loss: 1.0876	 Generator loss: 0.3308
# Iterations: 34922	 Discriminator loss: 1.1055	 Generator loss: 0.3450
# Iterations: 34923	 Discriminator loss: 1.1831	 Generator loss: 0.2986
# Iterations: 34924	 Discriminator loss: 0.7920	 Generator loss: 0.2763
# Iterations: 34925	 Discriminator loss: 1.1014	 Generator loss: 0.2788
# Iterations: 34926	 Discriminator loss: 1.3870	 Generator loss: 0.5546
# Iterations: 34927	 Discriminator loss: 1.0404	 Generator loss: 0.3550
# Iterations: 34928	 Discriminator loss: 1.3047	 Generator loss: 0.5531
# Iterations: 34929	 Discriminator loss: 1.0619	 Generator loss: 0.3343
# Iterations: 34930	 Discriminator loss: 1.2728	 Generator loss: 0.4905
# Iterations: 34931	 Discriminator loss: 1.2054	 Generator loss: 0.3782
# Iterations: 34932	 Discriminator loss: 0.9860	 Generator loss: 0.3558
# Iterations: 34933	 Discriminator loss: 0.7297	 Generator loss: 0.2615
# Iterations: 34934	 Discriminator loss: 1.1994	 Generator loss: 0.3305
# Iterations: 34935	 Discriminator loss: 0.7201	 Generator loss: 0.2599
# Iterations: 34936	 Discriminator loss: 1.1238	 Generator loss: 0.2566
# Iterations: 34937	 Discriminator loss: 1.2881	 Generator loss: 0.5717
# Iterations: 34938	 Discriminator loss: 1.2871	 Generator loss: 0.4896
# Iterations: 34939	 Discriminator loss: 1.0218	 Generator loss: 0.3191
# Iterations: 34940	 Discriminator loss: 1.2767	 Generator loss: 0.3233
# Iterations: 34941	 Discriminator loss: 0.7574	 Generator loss: 0.2715
# Iterations: 34942	 Discriminator loss: 1.0086	 Generator loss: 0.3625
# Iterations: 34943	 Discriminator loss: 0.9199	 Generator loss: 0.2975
# Iterations: 34944	 Discriminator loss: 0.9976	 Generator loss: 0.2836
# Iterations: 34945	 Discriminator loss: 1.1590	 Generator loss: 0.4533
# Iterations: 34946	 Discriminator loss: 1.1550	 Generator loss: 0.3956
# Iterations: 34947	 Discriminator loss: 1.0023	 Generator loss: 0.3114
# Iterations: 34948	 Discriminator loss: 0.9503	 Generator loss: 0.2594
# Iterations: 34949	 Discriminator loss: 1.2621	 Generator loss: 0.4739
# Iterations: 34950	 Discriminator loss: 1.3057	 Generator loss: 0.5551
# Iterations: 34951	 Discriminator loss: 1.2251	 Generator loss: 0.4841
# Iterations: 34952	 Discriminator loss: 0.9819	 Generator loss: 0.3277
# Iterations: 34953	 Discriminator loss: 1.1811	 Generator loss: 0.3320
# Iterations: 34954	 Discriminator loss: 1.0379	 Generator loss: 0.3181
# Iterations: 34955	 Discriminator loss: 0.7327	 Generator loss: 0.2596
# Iterations: 34956	 Discriminator loss: 1.0214	 Generator loss: 0.3035
# Iterations: 34957	 Discriminator loss: 1.1636	 Generator loss: 0.4149
# Iterations: 34958	 Discriminator loss: 1.3673	 Generator loss: 0.3466
# Iterations: 34959	 Discriminator loss: 1.1806	 Generator loss: 0.3274
# Iterations: 34960	 Discriminator loss: 1.1881	 Generator loss: 0.3246
# Iterations: 34961	 Discriminator loss: 0.7688	 Generator loss: 0.2613
# Iterations: 34962	 Discriminator loss: 0.9803	 Generator loss: 0.3599
# Iterations: 34963	 Discriminator loss: 1.0074	 Generator loss: 0.3088
# Iterations: 34964	 Discriminator loss: 1.1517	 Generator loss: 0.3330
# Iterations: 34965	 Discriminator loss: 0.6996	 Generator loss: 0.2522
# Iterations: 34966	 Discriminator loss: 1.3535	 Generator loss: 0.2995
# Iterations: 34967	 Discriminator loss: 1.3312	 Generator loss: 0.5094
# Iterations: 34968	 Discriminator loss: 1.2227	 Generator loss: 0.4070
# Iterations: 34969	 Discriminator loss: 1.2146	 Generator loss: 0.3427
# Iterations: 34970	 Discriminator loss: 0.8137	 Generator loss: 0.3111
# Iterations: 34971	 Discriminator loss: 0.8752	 Generator loss: 0.2600
# Iterations: 34972	 Discriminator loss: 1.5997	 Generator loss: 0.3076
# Iterations: 34973	 Discriminator loss: 1.1694	 Generator loss: 0.4887
# Iterations: 34974	 Discriminator loss: 1.1893	 Generator loss: 0.3628
# Iterations: 34975	 Discriminator loss: 0.8608	 Generator loss: 0.2805
# Iterations: 34976	 Discriminator loss: 1.2213	 Generator loss: 0.2411
# Iterations: 34977	 Discriminator loss: 1.2917	 Generator loss: 0.5793
# Iterations: 34978	 Discriminator loss: 1.1274	 Generator loss: 0.2997
# Iterations: 34979	 Discriminator loss: 1.3748	 Generator loss: 0.4677
# Iterations: 34980	 Discriminator loss: 0.8580	 Generator loss: 0.3096
# Iterations: 34981	 Discriminator loss: 1.0843	 Generator loss: 0.2686
# Iterations: 34982	 Discriminator loss: 1.4044	 Generator loss: 0.6004
# Iterations: 34983	 Discriminator loss: 1.2014	 Generator loss: 0.2919
# Iterations: 34984	 Discriminator loss: 1.3914	 Generator loss: 0.5819
# Iterations: 34985	 Discriminator loss: 1.0920	 Generator loss: 0.3138
# Iterations: 34986	 Discriminator loss: 1.1910	 Generator loss: 0.4295
# Iterations: 34987	 Discriminator loss: 0.9390	 Generator loss: 0.2996
# Iterations: 34988	 Discriminator loss: 1.2272	 Generator loss: 0.4759
# Iterations: 34989	 Discriminator loss: 1.1424	 Generator loss: 0.3316
# Iterations: 34990	 Discriminator loss: 1.3675	 Generator loss: 0.5531
# Iterations: 34991	 Discriminator loss: 1.0280	 Generator loss: 0.3593
# Iterations: 34992	 Discriminator loss: 0.9406	 Generator loss: 0.3478
# Iterations: 34993	 Discriminator loss: 0.7427	 Generator loss: 0.2642
# Iterations: 34994	 Discriminator loss: 1.0843	 Generator loss: 0.4158
# Iterations: 34995	 Discriminator loss: 0.9854	 Generator loss: 0.2759
# Iterations: 34996	 Discriminator loss: 1.2936	 Generator loss: 0.4348
# Iterations: 34997	 Discriminator loss: 0.9433	 Generator loss: 0.3047
# Iterations: 34998	 Discriminator loss: 0.8658	 Generator loss: 0.3058
# Iterations: 34999	 Discriminator loss: 1.0139	 Generator loss: 0.3251
# Iterations: 35000	 Discriminator loss: 1.4496	 Generator loss: 0.3967
